# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As it is spring in the Northern Hemisphere, the distribution of temperatures is approaching balanced over the Equator.
# * The distribution of randomly selected cities also demonstrates that the majority of people, and therefore cities, are located in the Northern Hemisphere.
# * While there does not appear to be a correlation between latitude, wind and clouds; there does appear to appear to be marginally more low humidity cities in the Northern Hemisphere.
# ---

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import csv


# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data = "output/cities_data.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 605

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
query_url = url + "appid=" + api_key + "&units=imperial" + "&q="
cnt = 1
fieldnames = ['City','Cloudiness','Country','Date','Humidity','Lat','Lng','High Temp','Wind Speed']


print("""
    Processing Records, please wait a while.
    ----------------------------------------
    """)


for city in cities:
    weather_response = requests.get(query_url + city)
    weather_json = weather_response.json()
    
    try:
        print(f"Processing Record {cnt} of {len(cities)} | {weather_json['name']}")
        cnt += 1
        cdata_out = {
            'City':weather_json['name'],
            'Cloudiness':weather_json['clouds']['all'],
            'Country':weather_json['sys']['country'],
            'Date':weather_json['dt'],
            'Humidity':weather_json['main']['humidity'],
            'Lat':weather_json['coord']['lat'],
            'Lng':weather_json['coord']['lon'],
            'High Temp':weather_json['main']['temp_max'],
            'Wind Speed':weather_json['wind']['speed']
        }
        
        if cnt == 2:
            with open(output_data, 'w') as csvfile:
                writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
                writer.writeheader()
                writer.writerow(cdata_out)
              
        else:
            with open(output_data, 'a') as csvfile:
                writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
                writer.writerow(cdata_out)             
              
              
    except KeyError:
        print("City not found. Skipping...")
        cnt += 1
# Out:
#     Processing Records, please wait a while.
#     ----------------------------------------
#
# Processing Record 1 of 605 | Aginskoye
# Processing Record 2 of 605 | Hobart
# Processing Record 3 of 605 | Bethel
# Processing Record 4 of 605 | Kapaa
# City not found. Skipping...
# Processing Record 6 of 605 | Cabo San Lucas
# Processing Record 7 of 605 | Bluff
# Processing Record 8 of 605 | Cape Town
# Processing Record 9 of 605 | Popova
# Processing Record 10 of 605 | Alice Springs
# Processing Record 11 of 605 | Jamestown
# Processing Record 12 of 605 | Carnarvon
# Processing Record 13 of 605 | Chokurdakh
# Processing Record 14 of 605 | Honningsvag
# City not found. Skipping...
# Processing Record 16 of 605 | Nouakchott
# Processing Record 17 of 605 | Kodiak
# Processing Record 18 of 605 | Ushuaia
# Processing Record 19 of 605 | Busselton
# Processing Record 20 of 605 | Fort-Shevchenko
# Processing Record 21 of 605 | Vila Franca do Campo
# Processing Record 22 of 605 | Rikitea
# Processing Record 23 of 605 | Mataura
# City not found. Skipping...
# Processing Record 25 of 605 | Copiapo
# Processing Record 26 of 605 | Nikolskoye
# Processing Record 27 of 605 | Genc
# Processing Record 28 of 605 | Punta Arenas
# Processing Record 29 of 605 | Butaritari
# Processing Record 30 of 605 | Vrangel
# Processing Record 31 of 605 | Saint Anthony
# Processing Record 32 of 605 | Puerto Ayora
# Processing Record 33 of 605 | Machado
# Processing Record 34 of 605 | Guerrero Negro
# Processing Record 35 of 605 | Vaini
# Processing Record 36 of 605 | Barrow
# Processing Record 37 of 605 | Lebu
# Processing Record 38 of 605 | Mahebourg
# Processing Record 39 of 605 | Koltubanovskiy
# Processing Record 40 of 605 | Meulaboh
# Processing Record 41 of 605 | Balkanabat
# Processing Record 42 of 605 | Qaanaaq
# Processing Record 43 of 605 | Manggar
# Processing Record 44 of 605 | Ribeira Grande
# Processing Record 45 of 605 | Camacha
# Processing Record 46 of 605 | Souillac
# Processing Record 47 of 605 | Eyrarbakki
# Processing Record 48 of 605 | Pisco
# Processing Record 49 of 605 | Moerai
# Processing Record 50 of 605 | Hamilton
# Processing Record 51 of 605 | Tuktoyaktuk
# Processing Record 52 of 605 | Turbat
# Processing Record 53 of 605 | Georgetown
# Processing Record 54 of 605 | Hithadhoo
# Processing Record 55 of 605 | Grafenau
# City not found. Skipping...
# Processing Record 57 of 605 | Roanoke Rapids
# Processing Record 58 of 605 | Isangel
# Processing Record 59 of 605 | Thompson
# Processing Record 60 of 605 | San Cristobal
# Processing Record 61 of 605 | Christchurch
# Processing Record 62 of 605 | Port Elizabeth
# Processing Record 63 of 605 | Coquimbo
# Processing Record 64 of 605 | Kavieng
# Processing Record 65 of 605 | Waipawa
# Processing Record 66 of 605 | Castro
# Processing Record 67 of 605 | Oeiras
# Processing Record 68 of 605 | Port Alfred
# Processing Record 69 of 605 | Chabahar
# Processing Record 70 of 605 | Batticaloa
# Processing Record 71 of 605 | Arlit
# Processing Record 72 of 605 | Ruston
# Processing Record 73 of 605 | Bandarbeyla
# Processing Record 74 of 605 | Hilo
# Processing Record 75 of 605 | Bojnurd
# Processing Record 76 of 605 | Ilulissat
# Processing Record 77 of 605 | Klaksvik
# Processing Record 78 of 605 | Kaitangata
# Processing Record 79 of 605 | Bubaque
# Processing Record 80 of 605 | Santa Cruz
# Processing Record 81 of 605 | Abbeville
# Processing Record 82 of 605 | Cherskiy
# Processing Record 83 of 605 | Clyde River
# Processing Record 84 of 605 | Saint-Philippe
# Processing Record 85 of 605 | Flinders
# Processing Record 86 of 605 | Rome
# Processing Record 87 of 605 | Teguldet
# Processing Record 88 of 605 | Mar del Plata
# Processing Record 89 of 605 | Sola
# Processing Record 90 of 605 | Tual
# Processing Record 91 of 605 | Yellowknife
# Processing Record 92 of 605 | Oranjemund
# Processing Record 93 of 605 | Hambantota
# Processing Record 94 of 605 | Amapa
# Processing Record 95 of 605 | Dutse
# Processing Record 96 of 605 | Riberalta
# Processing Record 97 of 605 | Nome
# Processing Record 98 of 605 | Tuatapere
# Processing Record 99 of 605 | Faanui
# Processing Record 100 of 605 | Sao Joao da Barra
# Processing Record 101 of 605 | Dunedin
# Processing Record 102 of 605 | Ponta do Sol
# Processing Record 103 of 605 | Husavik
# Processing Record 104 of 605 | Atuona
# Processing Record 105 of 605 | Muros
# Processing Record 106 of 605 | Lakes Entrance
# Processing Record 107 of 605 | Kargasok
# Processing Record 108 of 605 | Chuy
# Processing Record 109 of 605 | Havre
# Processing Record 110 of 605 | Upernavik
# Processing Record 111 of 605 | Rajkot
# Processing Record 112 of 605 | Lagoa
# Processing Record 113 of 605 | Victoria
# Processing Record 114 of 605 | Trairi
# Processing Record 115 of 605 | Kloulklubed
# Processing Record 116 of 605 | Constitucion
# Processing Record 117 of 605 | Inhambane
# Processing Record 118 of 605 | Saint-Augustin
# Processing Record 119 of 605 | Aqtobe
# City not found. Skipping...
# Processing Record 121 of 605 | Lima
# Processing Record 122 of 605 | Dikson
# Processing Record 123 of 605 | Palampur
# Processing Record 124 of 605 | Olinda
# Processing Record 125 of 605 | Luganville
# Processing Record 126 of 605 | Hermanus
# City not found. Skipping...
# Processing Record 128 of 605 | Albany
# Processing Record 129 of 605 | Waingapu
# Processing Record 130 of 605 | Havelock
# Processing Record 131 of 605 | Bredasdorp
# Processing Record 132 of 605 | Tiksi
# Processing Record 133 of 605 | Mogadishu
# Processing Record 134 of 605 | Severo-Kurilsk
# Processing Record 135 of 605 | Vanimo
# Processing Record 136 of 605 | Henties Bay
# Processing Record 137 of 605 | Newton Stewart
# Processing Record 138 of 605 | Kargil
# Processing Record 139 of 605 | Cidreira
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 142 of 605 | Hay River
# Processing Record 143 of 605 | Verkhniy baskunchak
# Processing Record 144 of 605 | Capao Bonito
# Processing Record 145 of 605 | Chapais
# Processing Record 146 of 605 | Lavrentiya
# Processing Record 147 of 605 | Altea
# Processing Record 148 of 605 | Hasaki
# Processing Record 149 of 605 | Luba
# Processing Record 150 of 605 | Bela
# Processing Record 151 of 605 | Pevek
# Processing Record 152 of 605 | Lubao
# City not found. Skipping...
# Processing Record 154 of 605 | Taltal
# City not found. Skipping...
# Processing Record 156 of 605 | Provideniya
# City not found. Skipping...
# Processing Record 158 of 605 | Salekhard
# City not found. Skipping...
# Processing Record 160 of 605 | Nagato
# Processing Record 161 of 605 | Bilma
# Processing Record 162 of 605 | Ixtapa
# Processing Record 163 of 605 | Lucelia
# Processing Record 164 of 605 | Darab
# Processing Record 165 of 605 | Onega
# Processing Record 166 of 605 | Lappeenranta
# Processing Record 167 of 605 | Quelimane
# Processing Record 168 of 605 | Pierre
# Processing Record 169 of 605 | Kruisfontein
# City not found. Skipping...
# Processing Record 171 of 605 | Fortuna
# Processing Record 172 of 605 | Laguna
# Processing Record 173 of 605 | Airai
# Processing Record 174 of 605 | Saskylakh
# Processing Record 175 of 605 | Shahrud
# Processing Record 176 of 605 | Safranbolu
# Processing Record 177 of 605 | Surt
# Processing Record 178 of 605 | Norman Wells
# City not found. Skipping...
# Processing Record 180 of 605 | Nanortalik
# Processing Record 181 of 605 | El Fuerte
# Processing Record 182 of 605 | Katsuura
# Processing Record 183 of 605 | Staryy Nadym
# City not found. Skipping...
# Processing Record 185 of 605 | Narsaq
# City not found. Skipping...
# Processing Record 187 of 605 | Batemans Bay
# City not found. Skipping...
# Processing Record 189 of 605 | Jangaon
# Processing Record 190 of 605 | Hualmay
# Processing Record 191 of 605 | Tawau
# Processing Record 192 of 605 | Berovo
# Processing Record 193 of 605 | Corinto
# Processing Record 194 of 605 | Ewa Beach
# Processing Record 195 of 605 | Ancud
# Processing Record 196 of 605 | Shiyan
# Processing Record 197 of 605 | Tamale
# Processing Record 198 of 605 | Graham
# Processing Record 199 of 605 | Dongkan
# Processing Record 200 of 605 | Tovuz
# Processing Record 201 of 605 | Hurricane
# Processing Record 202 of 605 | Mwinilunga
# Processing Record 203 of 605 | Kuruman
# Processing Record 204 of 605 | Sandusky
# Processing Record 205 of 605 | Brae
# Processing Record 206 of 605 | Plymouth
# Processing Record 207 of 605 | Ust-Ishim
# Processing Record 208 of 605 | Hobyo
# Processing Record 209 of 605 | Caravelas
# Processing Record 210 of 605 | Yeppoon
# Processing Record 211 of 605 | Ruteng
# Processing Record 212 of 605 | Hohhot
# Processing Record 213 of 605 | Skoghall
# Processing Record 214 of 605 | Mamallapuram
# Processing Record 215 of 605 | La Ligua
# Processing Record 216 of 605 | Guilin
# City not found. Skipping...
# Processing Record 218 of 605 | Buriti Alegre
# Processing Record 219 of 605 | Houma
# Processing Record 220 of 605 | Saldanha
# Processing Record 221 of 605 | Pine Bluff
# Processing Record 222 of 605 | Ust-Tsilma
# Processing Record 223 of 605 | Taoudenni
# Processing Record 224 of 605 | New Norfolk
# Processing Record 225 of 605 | San Patricio
# City not found. Skipping...
# Processing Record 227 of 605 | Mahanoro
# Processing Record 228 of 605 | Ust-Kuyga
# Processing Record 229 of 605 | Longyearbyen
# Processing Record 230 of 605 | Malpe
# Processing Record 231 of 605 | Qitaihe
# Processing Record 232 of 605 | Kamaishi
# Processing Record 233 of 605 | Mpulungu
# City not found. Skipping...
# Processing Record 235 of 605 | Marawi
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 238 of 605 | Jiamusi
# Processing Record 239 of 605 | Ancona
# Processing Record 240 of 605 | Leshukonskoye
# Processing Record 241 of 605 | Nara
# Processing Record 242 of 605 | Kabo
# Processing Record 243 of 605 | Tautira
# Processing Record 244 of 605 | Okha
# Processing Record 245 of 605 | Temyasovo
# Processing Record 246 of 605 | Sorong
# Processing Record 247 of 605 | Murchison
# Processing Record 248 of 605 | Velyka Bahachka
# Processing Record 249 of 605 | Saint George
# Processing Record 250 of 605 | Novyy Urengoy
# Processing Record 251 of 605 | Ugoofaaru
# Processing Record 252 of 605 | Presidencia Roque Saenz Pena
# City not found. Skipping...
# Processing Record 254 of 605 | Belyy Yar
# Processing Record 255 of 605 | Luyang
# Processing Record 256 of 605 | Bathsheba
# City not found. Skipping...
# Processing Record 258 of 605 | Tezu
# Processing Record 259 of 605 | Kavaratti
# City not found. Skipping...
# Processing Record 261 of 605 | Geraldton
# Processing Record 262 of 605 | Broome
# Processing Record 263 of 605 | Verkhniye Tatyshly
# Processing Record 264 of 605 | Murakami
# Processing Record 265 of 605 | Strelka
# Processing Record 266 of 605 | Salamiyah
# Processing Record 267 of 605 | Fort Nelson
# Processing Record 268 of 605 | Touros
# Processing Record 269 of 605 | Mount Gambier
# Processing Record 270 of 605 | Evensk
# Processing Record 271 of 605 | Port Lincoln
# Processing Record 272 of 605 | Khatanga
# Processing Record 273 of 605 | Port Blair
# Processing Record 274 of 605 | Rudnichnyy
# Processing Record 275 of 605 | Turukhansk
# Processing Record 276 of 605 | Bayeux
# Processing Record 277 of 605 | Same
# City not found. Skipping...
# Processing Record 279 of 605 | Simav
# Processing Record 280 of 605 | Samarai
# Processing Record 281 of 605 | Cap Malheureux
# Processing Record 282 of 605 | Shestakovo
# Processing Record 283 of 605 | Tamiahua
# Processing Record 284 of 605 | Mackay
# Processing Record 285 of 605 | Arraial do Cabo
# Processing Record 286 of 605 | Avarua
# Processing Record 287 of 605 | Apostolove
# Processing Record 288 of 605 | Tasiilaq
# City not found. Skipping...
# Processing Record 290 of 605 | Troitskoye
# Processing Record 291 of 605 | Fukue
# Processing Record 292 of 605 | Point Fortin
# Processing Record 293 of 605 | Helong
# Processing Record 294 of 605 | Gaoua
# Processing Record 295 of 605 | Baghdad
# Processing Record 296 of 605 | Gat
# Processing Record 297 of 605 | Westport
# Processing Record 298 of 605 | Bartica
# Processing Record 299 of 605 | Pacific Grove
# Processing Record 300 of 605 | Jati
# Processing Record 301 of 605 | Santiago
# Processing Record 302 of 605 | Azare
# Processing Record 303 of 605 | Tigil
# Processing Record 304 of 605 | Takoradi
# City not found. Skipping...
# Processing Record 306 of 605 | Ishigaki
# Processing Record 307 of 605 | Margate
# Processing Record 308 of 605 | Ayna
# Processing Record 309 of 605 | Berlevag
# Processing Record 310 of 605 | Beberibe
# Processing Record 311 of 605 | Port Said
# Processing Record 312 of 605 | Lata
# Processing Record 313 of 605 | Mitsamiouli
# Processing Record 314 of 605 | Santiago de Cao
# Processing Record 315 of 605 | Pandharpur
# Processing Record 316 of 605 | Kahului
# Processing Record 317 of 605 | Moree
# Processing Record 318 of 605 | San Pedro Buenavista
# Processing Record 319 of 605 | Tilichiki
# City not found. Skipping...
# Processing Record 321 of 605 | Elbistan
# Processing Record 322 of 605 | Wageningen
# Processing Record 323 of 605 | Alyangula
# Processing Record 324 of 605 | Ferkessedougou
# Processing Record 325 of 605 | Kyabe
# Processing Record 326 of 605 | Beloha
# City not found. Skipping...
# Processing Record 328 of 605 | Beatrice
# Processing Record 329 of 605 | Shubarshi
# Processing Record 330 of 605 | Rhyl
# Processing Record 331 of 605 | Seoul
# Processing Record 332 of 605 | Luderitz
# Processing Record 333 of 605 | Mecca
# City not found. Skipping...
# Processing Record 335 of 605 | Bambous Virieux
# City not found. Skipping...
# Processing Record 337 of 605 | Aitape
# Processing Record 338 of 605 | Chunskiy
# Processing Record 339 of 605 | Tura
# Processing Record 340 of 605 | East London
# Processing Record 341 of 605 | Mezen
# Processing Record 342 of 605 | San Quintin
# Processing Record 343 of 605 | Mandera
# City not found. Skipping...
# Processing Record 345 of 605 | Jinchang
# Processing Record 346 of 605 | Sogne
# Processing Record 347 of 605 | Omboue
# Processing Record 348 of 605 | Boden
# Processing Record 349 of 605 | Lincoln
# Processing Record 350 of 605 | Maunabo
# Processing Record 351 of 605 | Ibotirama
# Processing Record 352 of 605 | Kingaroy
# Processing Record 353 of 605 | Faxinal
# Processing Record 354 of 605 | Luanda
# Processing Record 355 of 605 | Mayo
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 358 of 605 | Celestun
# Processing Record 359 of 605 | Svetlogorsk
# Processing Record 360 of 605 | Birjand
# Processing Record 361 of 605 | Lamar
# Processing Record 362 of 605 | Port Hueneme
# Processing Record 363 of 605 | Petropavlovsk-Kamchatskiy
# Processing Record 364 of 605 | Dongsheng
# Processing Record 365 of 605 | Beringovskiy
# City not found. Skipping...
# Processing Record 367 of 605 | Aloleng
# Processing Record 368 of 605 | Nador
# Processing Record 369 of 605 | Sedam
# City not found. Skipping...
# Processing Record 371 of 605 | China
# City not found. Skipping...
# Processing Record 373 of 605 | Wanning
# Processing Record 374 of 605 | Valparaiso
# City not found. Skipping...
# Processing Record 376 of 605 | Tyret Pervaya
# Processing Record 377 of 605 | Itarema
# Processing Record 378 of 605 | Ginir
# Processing Record 379 of 605 | Liverpool
# Processing Record 380 of 605 | Melendugno
# Processing Record 381 of 605 | Rosarito
# Processing Record 382 of 605 | Sortavala
# Processing Record 383 of 605 | Manado
# Processing Record 384 of 605 | Ozernovskiy
# City not found. Skipping...
# Processing Record 386 of 605 | Damara
# City not found. Skipping...
# Processing Record 388 of 605 | Okahandja
# Processing Record 389 of 605 | Baryshivka
# Processing Record 390 of 605 | Kathu
# Processing Record 391 of 605 | Torbay
# Processing Record 392 of 605 | Katobu
# Processing Record 393 of 605 | Alofi
# Processing Record 394 of 605 | Quirinopolis
# Processing Record 395 of 605 | Kalmunai
# Processing Record 396 of 605 | Augustow
# Processing Record 397 of 605 | Asyut
# City not found. Skipping...
# Processing Record 399 of 605 | Shingu
# Processing Record 400 of 605 | Winnemucca
# Processing Record 401 of 605 | Lethem
# Processing Record 402 of 605 | Kirakira
# Processing Record 403 of 605 | Adelaide
# Processing Record 404 of 605 | Komsomolskiy
# Processing Record 405 of 605 | Kolondieba
# Processing Record 406 of 605 | Azle
# Processing Record 407 of 605 | Maniitsoq
# Processing Record 408 of 605 | Coihaique
# Processing Record 409 of 605 | Florianopolis
# Processing Record 410 of 605 | Saint-Pierre
# Processing Record 411 of 605 | Fairbanks
# Processing Record 412 of 605 | Mehamn
# Processing Record 413 of 605 | Lazaro Cardenas
# City not found. Skipping...
# Processing Record 415 of 605 | Gamba
# City not found. Skipping...
# Processing Record 417 of 605 | Sao Gabriel da Cachoeira
# Processing Record 418 of 605 | Mareeba
# Processing Record 419 of 605 | Yinchuan
# Processing Record 420 of 605 | Aksarka
# Processing Record 421 of 605 | Nanyamba
# Processing Record 422 of 605 | Wick
# Processing Record 423 of 605 | Alice
# Processing Record 424 of 605 | Tucurui
# Processing Record 425 of 605 | Peterhead
# City not found. Skipping...
# Processing Record 427 of 605 | San Martin
# City not found. Skipping...
# Processing Record 429 of 605 | Agadez
# City not found. Skipping...
# Processing Record 431 of 605 | Grenville
# Processing Record 432 of 605 | Itoman
# Processing Record 433 of 605 | Pringsewu
# Processing Record 434 of 605 | Leticia
# City not found. Skipping...
# Processing Record 436 of 605 | Stromness
# Processing Record 437 of 605 | Shenjiamen
# City not found. Skipping...
# Processing Record 439 of 605 | Saint-Raymond
# Processing Record 440 of 605 | Mmathubudukwane
# Processing Record 441 of 605 | Dingle
# Processing Record 442 of 605 | Mugla
# Processing Record 443 of 605 | Zhangye
# Processing Record 444 of 605 | Aklavik
# Processing Record 445 of 605 | Te Anau
# Processing Record 446 of 605 | Palm Coast
# Processing Record 447 of 605 | Boissevain
# Processing Record 448 of 605 | Katherine
# Processing Record 449 of 605 | Adrar
# Processing Record 450 of 605 | Luorong
# City not found. Skipping...
# Processing Record 452 of 605 | Port Keats
# Processing Record 453 of 605 | Ust-Nera
# Processing Record 454 of 605 | Hofn
# Processing Record 455 of 605 | Tuy Hoa
# Processing Record 456 of 605 | Zhangjiakou
# Processing Record 457 of 605 | Kenora
# Processing Record 458 of 605 | Kirovskiy
# Processing Record 459 of 605 | Biak
# Processing Record 460 of 605 | Keti Bandar
# Processing Record 461 of 605 | Boulder
# Processing Record 462 of 605 | Svetlaya
# Processing Record 463 of 605 | Qaqortoq
# Processing Record 464 of 605 | Manzanillo
# City not found. Skipping...
# Processing Record 466 of 605 | Rio Bueno
# Processing Record 467 of 605 | Tevaitoa
# Processing Record 468 of 605 | Liepaja
# Processing Record 469 of 605 | Port Augusta
# Processing Record 470 of 605 | Camalu
# Processing Record 471 of 605 | Haines Junction
# Processing Record 472 of 605 | Lompoc
# Processing Record 473 of 605 | Kinchil
# Processing Record 474 of 605 | Acajutla
# Processing Record 475 of 605 | Ponta Delgada
# Processing Record 476 of 605 | Yokadouma
# Processing Record 477 of 605 | Bangangte
# Processing Record 478 of 605 | Yantal
# Processing Record 479 of 605 | Lorengau
# Processing Record 480 of 605 | Beitbridge
# Processing Record 481 of 605 | Okato
# Processing Record 482 of 605 | Portland
# Processing Record 483 of 605 | Suntar
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 486 of 605 | Rafraf
# Processing Record 487 of 605 | Dolgoye
# City not found. Skipping...
# Processing Record 489 of 605 | Nuuk
# Processing Record 490 of 605 | Polunochnoye
# Processing Record 491 of 605 | Salobrena
# Processing Record 492 of 605 | Tignere
# Processing Record 493 of 605 | Noumea
# Processing Record 494 of 605 | Tanete
# Processing Record 495 of 605 | Atar
# Processing Record 496 of 605 | Zasheyek
# Processing Record 497 of 605 | Paamiut
# Processing Record 498 of 605 | Alpena
# Processing Record 499 of 605 | Rockingham
# City not found. Skipping...
# Processing Record 501 of 605 | Zyryanka
# Processing Record 502 of 605 | Cabedelo
# Processing Record 503 of 605 | Plettenberg Bay
# Processing Record 504 of 605 | Yarada
# Processing Record 505 of 605 | Mayahi
# Processing Record 506 of 605 | Kigoma
# Processing Record 507 of 605 | Makakilo City
# Processing Record 508 of 605 | Redmond
# City not found. Skipping...
# Processing Record 510 of 605 | Bandar-e Anzali
# Processing Record 511 of 605 | Srednekolymsk
# Processing Record 512 of 605 | Boma
# Processing Record 513 of 605 | Salinopolis
# Processing Record 514 of 605 | White Oak
# Processing Record 515 of 605 | Umba
# City not found. Skipping...
# Processing Record 517 of 605 | Samur
# Processing Record 518 of 605 | Preeceville
# Processing Record 519 of 605 | Vila Velha
# Processing Record 520 of 605 | Verkhnevilyuysk
# Processing Record 521 of 605 | Miedzychod
# City not found. Skipping...
# Processing Record 523 of 605 | Los Llanos de Aridane
# Processing Record 524 of 605 | Kharp
# Processing Record 525 of 605 | Murray Bridge
# Processing Record 526 of 605 | Lebanon
# Processing Record 527 of 605 | Sovetskiy
# Processing Record 528 of 605 | Madang
# Processing Record 529 of 605 | Alta Floresta
# Processing Record 530 of 605 | Havre-Saint-Pierre
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 533 of 605 | Iracoubo
# Processing Record 534 of 605 | Apiai
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 537 of 605 | Motatei
# Processing Record 538 of 605 | Massakory
# Processing Record 539 of 605 | Fort Wellington
# Processing Record 540 of 605 | Locri
# Processing Record 541 of 605 | Marau
# Processing Record 542 of 605 | Port-Cartier
# Processing Record 543 of 605 | Guiberoua
# Processing Record 544 of 605 | Kamina
# Processing Record 545 of 605 | Leningradskiy
# Processing Record 546 of 605 | Seymchan
# City not found. Skipping...
# Processing Record 548 of 605 | Kiunga
# Processing Record 549 of 605 | North Ogden
# Processing Record 550 of 605 | Derzhavinsk
# Processing Record 551 of 605 | San Alberto
# Processing Record 552 of 605 | Iguape
# Processing Record 553 of 605 | Aswan
# Processing Record 554 of 605 | Shache
# Processing Record 555 of 605 | Kopong
# Processing Record 556 of 605 | Quatre Cocos
# Processing Record 557 of 605 | Sinnamary
# Processing Record 558 of 605 | Khuzdar
# Processing Record 559 of 605 | Belmonte
# Processing Record 560 of 605 | Jumla
# Processing Record 561 of 605 | Taksimo
# Processing Record 562 of 605 | Kautokeino
# Processing Record 563 of 605 | Cockburn Town
# Processing Record 564 of 605 | Shinshiro
# Processing Record 565 of 605 | Daru
# Processing Record 566 of 605 | Shadegan
# Processing Record 567 of 605 | Berezniki
# Processing Record 568 of 605 | Jiuquan
# Processing Record 569 of 605 | Davila
# Processing Record 570 of 605 | Guanica
# Processing Record 571 of 605 | Sitka
# Processing Record 572 of 605 | Uthal
# Processing Record 573 of 605 | Basco
# Processing Record 574 of 605 | San Vicente
# City not found. Skipping...
# Processing Record 576 of 605 | Yar-Sale
# Processing Record 577 of 605 | Amahai
# Processing Record 578 of 605 | Anchorage
# Processing Record 579 of 605 | Namibe
# Processing Record 580 of 605 | Shubarkuduk
# Processing Record 581 of 605 | Nabire
# Processing Record 582 of 605 | Nhulunbuy
# Processing Record 583 of 605 | Khandbari
# Processing Record 584 of 605 | Chilca
# Processing Record 585 of 605 | Buraydah
# Processing Record 586 of 605 | Sibolga
# Processing Record 587 of 605 | Moron
# Processing Record 588 of 605 | Lumajang
# Processing Record 589 of 605 | Iqaluit
# Processing Record 590 of 605 | Otofuke
# Processing Record 591 of 605 | Tazovskiy
# Processing Record 592 of 605 | Palmer
# Processing Record 593 of 605 | Nantucket
# Processing Record 594 of 605 | Nazas
# Processing Record 595 of 605 | Solwezi
# City not found. Skipping...
# Processing Record 597 of 605 | Yulara
# Processing Record 598 of 605 | Kareli
# Processing Record 599 of 605 | Rio Grande
# Processing Record 600 of 605 | Codrington
# City not found. Skipping...
# Processing Record 602 of 605 | Halifax
# Processing Record 603 of 605 | Alferrarede
# Processing Record 604 of 605 | Macultepec
# Processing Record 605 of 605 | Dillon

# %%
weather_df = pd.read_csv(output_data, header=0)

weather_df = weather_df.dropna()

weather_df.count()
# Out:
# City          536
# Cloudiness    536
# Country       536
# Date          536
# Humidity      536
# Lat           536
# Lng           536
# High Temp     536
# Wind Speed    536
# dtype: int64

# %%
weather_df.head()
# Out:
#              City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0       Aginskoye           0      RU  1555808842        23  51.11  114.54
# 1          Hobart           0      AU  1555808715        56 -42.88  147.33
# 2          Bethel          90      US  1555806600        92  60.79 -161.76
# 3           Kapaa          20      US  1555808615        61  22.08 -159.32
# 4  Cabo San Lucas          20      MX  1555808562        23  22.89 -109.91
#
#    High Temp  Wind Speed
# 0      33.68        1.41
# 1      75.00       10.29
# 2      30.20        8.72
# 3      80.60       12.75
# 4      87.80       11.41

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)


ax1.scatter(weather_df['Lat'], weather_df['High Temp'], s=10, c='skyblue', edgecolor='k', marker="o", alpha=0.7)

ax1.grid(True)

plt.ylabel('Temperature (F)')
plt.xlabel('Latitude')
ax1.set_title('Global High Temperatures by Latitude | April 20, 2019')

plt.show()
plt.savefig("output/temp_v_lat.png")

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)


ax1.scatter(weather_df['Lat'], weather_df['Humidity'], s=10, c='skyblue', edgecolor='k', marker="o", alpha=0.7)

ax1.grid(True)

plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')
ax1.set_title('Global Humidity by Latitude | April 20, 2019')

plt.show()
plt.savefig("output/humidity_v_lat.png")

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)


ax1.scatter(weather_df['Lat'], weather_df['Cloudiness'], s=10, c='skyblue', edgecolor='k', marker="o", alpha=0.7)

ax1.grid(True)

plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')
ax1.set_title('Global Cloudiness by Latitude | April 20, 2019')

plt.show
plt.savefig("output/cloudiness_v_lat.png")

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)


ax1.scatter(weather_df['Lat'], weather_df['Wind Speed'], s=10, c='skyblue', edgecolor='k', marker="o", alpha=0.7)

ax1.grid(True)

plt.ylabel('Wind Speed (mph)')
plt.xlabel('Latitude')
ax1.set_title('Global Wind Speed by Latitude | April 20, 2019')

plt.show()
plt.savefig("output/wind_v_lat.png")
